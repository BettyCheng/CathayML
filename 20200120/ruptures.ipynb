# %%
import ruptures as rp

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ###  Piecewise Stationary

# %% [markdown]
# #### Pelt

# %%
import matplotlib.pyplot as plt
import ruptures as rpt

# generate signal
n_samples, dim, sigma = 1000, 3, 4
n_bkps = 4  # number of breakpoints
signal, bkps = rpt.pw_constant(n_samples, dim, n_bkps, noise_std=sigma)

# detection
algo = rpt.Pelt(model="rbf").fit(signal)
result = algo.predict(pen=10)

# display
rpt.display(signal, bkps, result)
plt.show()

# %%
import matplotlib.pyplot as plt
import ruptures as rpt

# generate signal
n_samples, dim, sigma = 1000, 3, 4
n_bkps = 4  # number of breakpoints
signal, bkps = rpt.pw_constant(n_samples, dim, n_bkps, noise_std=sigma)

# detection
algo = rpt.Dynp(model="l1").fit(signal)
result = algo.predict(n_bkps=4)

# display
rpt.display(signal, bkps, result)
plt.show()

# %%
import matplotlib.pyplot as plt
import ruptures as rpt

# generate signal
n_samples, dim, sigma = 1000, 3, 4
n_bkps = 4  # number of breakpoints
signal, bkps = rpt.pw_constant(n_samples, dim, n_bkps, noise_std=sigma)

# detection
algo = rpt.Binseg(model="l1").fit(signal)
result = algo.predict(n_bkps=4)

# display
rpt.display(signal, bkps, result)
plt.show()

# %%
import matplotlib.pyplot as plt
import ruptures as rpt

# generate signal
n_samples, dim, sigma = 1000, 3, 4
n_bkps = 4  # number of breakpoints
signal, bkps = rpt.pw_constant(n_samples, dim, n_bkps, noise_std=sigma)

# detection
algo = rpt.Window(model="l1").fit(signal)
result = algo.predict(n_bkps=3)

# display
rpt.display(signal, bkps, result)
plt.show()

# %% [markdown]
# ### Unknown K

# %%
series=pd.read_csv('TWII.csv',encoding='big5').iloc[:,3].values

# %%
sns.lineplot(data=series)

# %%
sns.lineplot(data=)

# %%
import matplotlib.pyplot as plt
import ruptures as rpt

# generate signal
signal=np.diff(np.log(series))

# detection
algo = rpt.Pelt(model='rbf').fit(signal)
result = algo.predict(pen=1.3)

# display
rpt.display(signal, result)
plt.show()

# %%
rpt.display(series, result)
# Out:
# (<Figure size 720x144 with 1 Axes>,
#  [<matplotlib.axes._subplots.AxesSubplot at 0x125a903c8>])
